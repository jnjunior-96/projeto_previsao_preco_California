# %% [markdown]
# ### Importações
#
#
# ## Testando o Ridge

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from joblib import dump

from src.config import DADOS_LIMPOS, MODELO_FINAL
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_households  population_per_households  \
# 0                  5              6.984127                   2.555556
# 1                  5              6.238137                   2.109842
# 2                  2              4.294117                   2.026891
# 3                  2              4.242424                   2.640152
# 4                  2              5.343676                   2.362768
#
#    bedrooms_per_rooms
# 0            0.146591
# 1            0.155797
# 2            0.260274
# 3            0.252679
# 4            0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   longitude                  17564 non-null  float32
#  1   latitude                   17564 non-null  float32
#  2   housing_median_age         17564 non-null  int8
#  3   total_rooms                17564 non-null  int16
#  4   total_bedrooms             17564 non-null  int16
#  5   population                 17564 non-null  int16
#  6   households                 17564 non-null  int16
#  7   median_income              17564 non-null  float32
#  8   median_house_value         17564 non-null  int32
#  9   ocean_proximity            17564 non-null  category
#  10  median_income_cat          17564 non-null  int64
#  11  rooms_per_households       17564 non-null  float32
#  12  population_per_households  17564 non-null  float32
#  13  bedrooms_per_rooms         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %% [markdown]
# Separando colunas categóricas, target e categóricas ordinais, para cada tratamento

# %%
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"]

coluna_ordinal_encoder = ["median_income_cat"]

# %% [markdown]
# Colunas numéricas para tratamento com RobustScaler

# %%
colunas_robust_scaler = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder)

colunas_robust_scaler
# Out:
# Index(['bedrooms_per_rooms', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_households',
#        'rooms_per_households', 'total_bedrooms', 'total_rooms'],
#       dtype='object')

# %% [markdown]
# Ciando a pipeline

# %%
pipeline_robust = Pipeline(steps=[
    ("robust_scaler", RobustScaler()),
    ("poly", PolynomialFeatures(degree=1, include_bias=False))
])

preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
        ("robust_scaler_poly", pipeline_robust, colunas_robust_scaler),
    ],
)

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_households  population_per_households  bedrooms_per_rooms
# 0              6.984127                   2.555556            0.146591
# 1              6.238137                   2.109842            0.155797
# 2              4.294117                   2.026891            0.260274
# 3              4.242424                   2.640152            0.252679
# 4              5.343676                   2.362768            0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %% [markdown]
# Definindo os parametros

# %%
param_grid = {
    "regressor__preprocessor__robust_scaler_poly__poly__degree":[1,2,3],
    "regressor__reg__alpha": [1E-2,5E-2,0.1,02.25,0.5,1.0,2.0,5.0,10.0,20.0,50.0],
}

# %% [markdown]
# Criando o grid_search com Ridge

# %%
grid_search = grid_search_cv_regressor(
    regressor=Ridge(),
    preprocessor=preprocessamento,
    target_transformer=QuantileTransformer(output_distribution="normal"),
    param_grid=param_grid,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                                              Ridge())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 2.25, 0.5,
#                                                    1.0, 2.0, 5.0, 10.0, 20.0,
#                                                    50.0]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %% [markdown]
# Treinando o meodelo

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 33 candidates, totalling 165 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                                              Ridge())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 2.25, 0.5,
#                                                    1.0, 2.0, 5.0, 10.0, 20.0,
#                                                    50.0]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 3,
#  'regressor__reg__alpha': 10.0}

# %%
grid_search.best_score_
# Out:
# np.float64(-50459.78088948543)

# %% [markdown]
# Visualizando a atuação de cada coeficiente

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                                     coeficiente
# robust_scaler_poly__longitude                         -1.021062
# robust_scaler_poly__latitude                          -0.956152
# one_hot__ocean_proximity_INLAND                       -0.461582
# robust_scaler_poly__latitude longitude populati...    -0.419054
# robust_scaler_poly__population_per_households         -0.331011
# ...                                                         ...
# robust_scaler_poly__latitude^2 longitude               0.245366
# robust_scaler_poly__housing_median_age median_i...     0.245872
# robust_scaler_poly__latitude median_income popu...     0.252805
# robust_scaler_poly__bedrooms_per_rooms                 0.337126
# robust_scaler_poly__median_income                      0.978217
#
# [367 rows x 1 columns]

# %% [markdown]
# Devido a utilização do PolynomialFeatures temos muitas features que aumenta a complexidade

# %%
plot_coeficientes(coefs)

# %%
coefs[coefs["coeficiente"]==0]
# Out:
# Empty DataFrame
# Columns: [coeficiente]
# Index: []

# %%
coefs[coefs["coeficiente"].between(-0.2,0.2)]
# Out:
#                                                     coeficiente
# one_hot__ocean_proximity_NEAR BAY                     -0.197058
# robust_scaler_poly__households median_income^2        -0.182103
# robust_scaler_poly__longitude median_income           -0.181756
# robust_scaler_poly__housing_median_age median_i...    -0.180435
# robust_scaler_poly__bedrooms_per_rooms rooms_pe...    -0.179126
# ...                                                         ...
# robust_scaler_poly__total_bedrooms                     0.168848
# robust_scaler_poly__bedrooms_per_rooms rooms_pe...     0.173305
# robust_scaler_poly__median_income population po...     0.175659
# robust_scaler_poly__median_income population ro...     0.177299
# robust_scaler_poly__bedrooms_per_rooms median_i...     0.183943
#
# [340 rows x 1 columns]

# %% [markdown]
# Separando em uma faixa de valores menor para se ter uma melhor visualização

# %%
plot_coeficientes(coefs[~coefs["coeficiente"].between(-0.2,0.2)])

# %% [markdown]
# Comparando os regressores

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": QuantileTransformer(output_distribution="normal"),
    },
    "Ridge_grid_search": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}


resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                       model  fit_time score_time   test_r2  \
# 0            DummyRegressor  0.002829   0.003128 -0.000081
# 1            DummyRegressor  0.001853   0.003284 -0.000146
# 2            DummyRegressor  0.001952   0.003487 -0.001737
# 3            DummyRegressor  0.002102   0.003336 -0.000101
# 4            DummyRegressor  0.002133   0.003433 -0.000114
# 5          LinearRegression  0.021762   0.009155  0.682162
# 6          LinearRegression  0.020764   0.007452   0.66999
# 7          LinearRegression  0.017664   0.007383  0.649247
# 8          LinearRegression  0.017702   0.009277  0.669873
# 9          LinearRegression  0.017372   0.007251  0.669023
# 10  LinearRegression_target  0.023535     0.0092  0.692072
# 11  LinearRegression_target  0.023724   0.008858  0.678421
# 12  LinearRegression_target  0.024139   0.008652  0.653576
# 13  LinearRegression_target  0.022437   0.008746   0.68405
# 14  LinearRegression_target  0.027028   0.007966  0.682781
# 15        Ridge_grid_search  0.090168   0.014974  0.744382
# 16        Ridge_grid_search  0.082477   0.014376  0.723743
# 17        Ridge_grid_search  0.087211   0.014338  0.697964
# 18        Ridge_grid_search  0.111936   0.016406  0.725435
# 19        Ridge_grid_search  0.089101    0.01648  0.725567
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.005956
# 1                 -75787.787194                    -95217.629397     0.005137
# 2                 -76753.598961                    -96253.253947     0.005439
# 3                 -76837.804811                    -95983.885799     0.005439
# 4                 -76617.245449                    -96182.764729     0.005566
# 5                 -39855.690996                    -54254.958188     0.030917
# 6                 -40272.565467                    -54695.230283     0.028216
# 7                  -42178.05929                    -56955.988706     0.025047
# 8                 -40806.492497                    -55146.318803     0.026979
# 9                 -40788.496497                     -55331.35106     0.024622
# 10                -37797.292375                    -53402.496877     0.032735
# 11                 -38264.55503                    -53992.033977     0.032583
# 12                -40302.811991                    -56603.425871     0.032791
# 13                -38590.084442                     -53949.29996     0.031183
# 14                -38409.017508                    -54169.121264     0.034993
# 15                -34108.671167                    -48655.542782     0.105142
# 16                -35020.004685                    -50042.851717     0.096854
# 17                -37078.177922                     -52852.77285     0.101549
# 18                -35241.273917                     -50291.96174     0.128342
# 19                -35275.142922                    -50383.740286     0.105582

# %%
df_resultados.groupby("model").mean()
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.002174   0.003334 -0.000436
# LinearRegression         0.019053   0.008104  0.668059
# LinearRegression_target  0.024172   0.008684   0.67818
# Ridge_grid_search        0.092179   0.015315  0.723418
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                        -40780.26095
# LinearRegression_target                -38672.752269
# Ridge_grid_search                      -35344.654122
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.005507
# LinearRegression                           -55276.769408     0.027156
# LinearRegression_target                     -54423.27559     0.032857
# Ridge_grid_search                          -50445.373875     0.107494

# %%
df_resultados.groupby("model").mean().sort_values(by="test_neg_root_mean_squared_error")
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.002174   0.003334 -0.000436
# LinearRegression         0.019053   0.008104  0.668059
# LinearRegression_target  0.024172   0.008684   0.67818
# Ridge_grid_search        0.092179   0.015315  0.723418
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                        -40780.26095
# LinearRegression_target                -38672.752269
# Ridge_grid_search                      -35344.654122
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.005507
# LinearRegression                           -55276.769408     0.027156
# LinearRegression_target                     -54423.27559     0.032857
# Ridge_grid_search                          -50445.373875     0.107494

# %% [markdown]
# Nota-se que o Ridge teve as melhores métricas com uma penalização de 3 vezes o tempo de processamento, devido a utilização do PolynomialFeature grau 3

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, fracao_amostra=0.1, eng_formatter=True)

# %% [markdown]
# Salvando o modelo para ser utilizado no StreamLit

# %%
dump(grid_search.best_estimator_, MODELO_FINAL)
# Out:
# ['C:\\Users\\User\\Desktop\\GDrive\\Ciência de Dados\\Machine Learning\\Regressão Linear\\05_projeto\\modelos\\ridge_polyfeat_target_quantile.joblib']
